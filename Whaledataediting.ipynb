# %%
import pandas as pd

# %%
pd.read_csv('Datasets/file.csv')

# %%
df = pd.read_csv('Datasets/whalescalCOFI91-06.csv', )
df
# Out:
#      dataset_id     row_id   latitude   longitude species_name  \
# 0           507  507_54185  33.495501 -120.925970         BLWH
# 1           507  507_54158  33.053163 -120.235435         SPWH
# 2           507  507_54156  33.083802 -120.182388         FIWH
# 3           507  507_53742  34.758781 -121.461095         KIWH
# 4           507  507_53709  33.645650 -123.826268         SPWH
# 5           507  507_53184  31.146182 -121.051945         BLWH
# 6           507  507_53873  32.459103 -118.325229         FIWH
# 7           507  507_70221  37.123737 -122.590596         HUWH
# 8           507  507_70208  37.084725 -122.543846         HUWH
# 9           507  507_70202  37.045968 -122.496751         HUWH
# 10          507  507_70169  36.987832 -122.426109         HUWH
# 11          507  507_70164  36.968453 -122.402562         HUWH
# 12          507  507_70111  36.848031 -122.221543         HUWH
# 13          507  507_70095  36.626386 -122.303799         HUWH
# ...

# %%
df['oceano'][0]
# Out:
# '{"oid": "507_54185", "obsDate": "2006-10-31", "longitude": -120.926, "latitude": 33.496, "SST": {"PF51": {"YEAR": 14.775, "MONTH": 16.575, "8DAYS": 16.05}, "OISST": {"DAY": 16.04, "8DAYS": 16.45, "MONTH": 16.87, "YEAR": 14.93}, "MODIS": {"DAY": -9999, "8DAYS": -9999, "MONTH": 17.67, "YEAR": 15.23}, "HYCOM": {"MONTH": 17.06, "YEAR": 15.57}}, "SSH": {"AVISO": {"8DAYS": 62.77}}, "CHLOR-A": {"SeaWiFS_etc": {"YEAR": 0.74, "MONTH": 0.27}, "MODIS": {"DAY": -9999, "8DAYS": 0.44, "MONTH": 0.32, "YEAR": 0.92}, "SeaWiFS": {"DAY": 0.53, "8DAYS": 0.46, "MONTH": 0.29, "YEAR": 0.75}}, "BATH": {"S2004": -3557, "ETOPO1": -3595.0}, "ZONE": {"EEZ": [{"MRGID": 8456, "COUNTRY": "United States", "SOVEREIGN": "United States"}], "LME": [{"LME_NUMBER": 3, "LME_NAME": "California Current"}], "MEOW": [{"ECO_CODE": 25058, "PROVINCE": "Cold Temperate Northeast Pacific"}]}, "SALINITY": {"HYCOM": {"MONTH": 33.42, "YEAR": 33.47}}}'

# %%
df = df[['latitude', 'longitude', 'species_name', 'common_name', 'group_size', 'date_time']]

# %%
df.to_csv('Datasets/whalescalCOFI91-06_v2.csv', index = False)

# %%
pd.read_csv('Datasets/whalescalCOFI91-06_v2.csv')
# Out:
#       latitude   longitude species_name               common_name  group_size  \
# 0    33.495501 -120.925970         BLWH                Blue Whale           1
# 1    33.053163 -120.235435         SPWH               Sperm Whale           2
# 2    33.083802 -120.182388         FIWH                 Fin Whale           3
# 3    34.758781 -121.461095         KIWH              Killer Whale           2
# 4    33.645650 -123.826268         SPWH               Sperm Whale           4
# 5    31.146182 -121.051945         BLWH                Blue Whale           1
# 6    32.459103 -118.325229         FIWH                 Fin Whale           1
# 7    37.123737 -122.590596         HUWH            Humpback Whale           1
# 8    37.084725 -122.543846         HUWH            Humpback Whale           5
# 9    37.045968 -122.496751         HUWH            Humpback Whale           1
# 10   36.987832 -122.426109         HUWH            Humpback Whale           1
# ...
